# %% [markdown]
# # Initial Movie Data Exploration

# %% [markdown]
# Loaded the Data with Pandas
#
# - Import and alias `pandas` as `pd`
# - Import and alias `seaborn` as `sns`
# - Import and alias `matplotlib.pyplot` as `plt`
# - Set Matplotlib visualizations to display inline in the notebook

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### MEASURING MOVIE "POPULARITY" WITH SCATTER PLOT

# %% [markdown]
# Combining `imdb.title.ratings` and `imdb.title.basics` to draw a comparison between the average movie rating, and the number of times it was rated.

# %%
# !ls
# Out:
# Combo_Notebook_Draft_0915.ipynb imdb.title.principals.csv.gz
# bom.movie_gross.csv.gz          imdb.title.ratings.csv.gz
# imdb.name.basics.csv.gz         rt.movie_info.tsv.gz
# imdb.title.akas.csv.gz          rt.reviews.tsv.gz
# imdb.title.basics.csv.gz        tmdb.movies.csv.gz
# imdb.title.crew.csv.gz          tn.movie_budgets.csv.gz

# %% [markdown]
# initializing a dataframe to access a database containing relevant csv.gz and tsv.gz files

# %%
rotten = pd.read_csv('rt.movie_info.tsv.gz', delimiter="\t")
rtreviews = pd.read_csv('rt.reviews.tsv.gz', sep="\t", encoding='latin-1')
imdbreviews = pd.read_csv("imdb.title.ratings.csv.gz")
basics = pd.read_csv('imdb.title.basics.csv.gz')

# %% [markdown]
# Exploring `imdbreviews` and `basics` first 5 rows

# %%
imdbreviews.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %% [markdown]
# Merging `basics` with `imdbreviews`dataFrames and checking the new `imdb` dataFrame

# %%
imdb = basics.merge(imdbreviews, on="tconst", how="inner")
imdb
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes                genres  averagerating  \
# 0            2013            175.0    Action,Crime,Drama            7.0
# 1            2019            114.0       Biography,Drama            7.2
# 2            2018            122.0                 Drama            6.9
# 3            2018              NaN          Comedy,Drama            6.1
# 4            2017             80.0  Comedy,Drama,Fantasy            6.5
# ...           ...              ...                   ...            ...
# 73851        2019             75.0           Documentary            6.2
# 73852        2019             98.0          Drama,Family            8.7
# 73853        2017              NaN           Documentary            8.5
# 73854        2019              NaN                   NaN            6.6
# 73855        2019             72.0           Documentary            6.5
#
#        numvotes
# 0            77
# 1            43
# 2          4517
# 3            13
# 4           119
# ...         ...
# 73851         6
# 73852       136
# 73853         8
# 73854         5
# 73855        11
#
# [73856 rows x 8 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Dropping duplicates from the `primary_title` column and checking its first 20 rows

# %%
imdb = imdb.drop_duplicates(subset=["primary_title"])
imdb.head(20)
# Out:
#        tconst                       primary_title  \
# 0   tt0063540                           Sunghursh
# 1   tt0066787     One Day Before the Rainy Season
# 2   tt0069049          The Other Side of the Wind
# 3   tt0069204                     Sabse Bada Sukh
# 4   tt0100275            The Wandering Soap Opera
# 5   tt0112502                             Bigfoot
# 6   tt0137204                     Joe Finds Grace
# 7   tt0146592                         Pál Adrienn
# 8   tt0154039                So Much for Justice!
# 9   tt0159369  Cooper and Hemingway: The True Gen
# 10  tt0162942        Children of the Green Dragon
# 11  tt0170651                T.G.M. - osvoboditel
# 12  tt0176694                  The Tragedy of Man
# 13  tt0192528                       Heaven & Hell
# 14  tt0230212                   The Final Journey
# 15  tt0247643    Los pájaros se van con la muerte
# 16  tt0249516                          Foodfight!
# 17  tt0250404                           Godfather
# 18  tt0253093                        Gangavataran
# 19  tt0255820                   Return to Babylon
#
#                         original_title  start_year  runtime_minutes  \
# 0                            Sunghursh        2013            175.0
# 1                      Ashad Ka Ek Din        2019            114.0
# 2           The Other Side of the Wind        2018            122.0
# 3                      Sabse Bada Sukh        2018              NaN
# 4                La Telenovela Errante        2017             80.0
# 5                              Bigfoot        2017              NaN
# 6                      Joe Finds Grace        2017             83.0
# 7                          Pál Adrienn        2010            136.0
# 8                       Oda az igazság        2010            100.0
# 9   Cooper and Hemingway: The True Gen        2013            180.0
# 10            A zöld sárkány gyermekei        2010             89.0
# 11                T.G.M. - osvoboditel        2018             60.0
# 12                 Az ember tragédiája        2011            160.0
# 13                      Reverse Heaven        2018            104.0
# 14                   The Final Journey        2010            120.0
# 15    Los pájaros se van con la muerte        2011            110.0
# 16                          Foodfight!        2012             91.0
# 17                           Godfather        2012              NaN
# 18                        Gangavataran        2018            134.0
# 19                   Return to Babylon        2013             75.0
#
#                         genres  averagerating  numvotes
# 0           Action,Crime,Drama            7.0        77
# 1              Biography,Drama            7.2        43
# 2                        Drama            6.9      4517
# 3                 Comedy,Drama            6.1        13
# 4         Comedy,Drama,Fantasy            6.5       119
# 5              Horror,Thriller            4.1        32
# 6   Adventure,Animation,Comedy            8.1       263
# 7                        Drama            6.8       451
# 8                      History            4.6        64
# 9                  Documentary            7.6        53
# 10                       Drama            6.9       120
# 11                 Documentary            7.5         6
# 12     Animation,Drama,History            7.8       584
# 13                       Drama            4.0        72
# 14                       Drama            8.8         8
# 15               Drama,Mystery            4.0        12
# 16     Action,Animation,Comedy            1.9      8248
# 17                 Crime,Drama            6.7       236
# 18                         NaN            6.6         8
# 19      Biography,Comedy,Drama            5.9       123

# %% [markdown]
# Getting more information about our column `primary_title`

# %%
imdb["primary_title"].describe()
# Out:
# count             69993
# unique            69993
# top       Melvin Smarty
# freq                  1
# Name: primary_title, dtype: object

# %% [markdown]
# ### Plotting

# %% [markdown]
# - Making a scatter plot to assess if there is a correlation between the "Movie Rating" and "Number of Votes per Movie".
# - Gathering insights on whether the number of ratings is a measure of popularity.

# %%
scatter_title = "Movie Popularity: Rating vs # of Times Rated"
xlabel = "Movie Rating"
ylabel = "Number of Votes per Movie"

imdb_pop, ax = plt.subplots(figsize=(10,6))
xx=imdb["averagerating"]
yy=imdb["numvotes"]

ax.scatter(xx,yy)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.set_title(scatter_title)
# Out:
# Text(0.5, 1.0, 'Movie Popularity: Rating vs # of Times Rated')

# %% [markdown]
# ## END POPULARITY MEASURING HERE

# %% [markdown]
# #### BEGIN: RELATIONSHIP BETWEEN BUDGET AND AVG MOVIE RATING

# %%
budgetinfo = pd.read_csv("tn.movie_budgets.csv.gz")
#import budget numbers

# %%
budgetinfo.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#rewrite the release_date to isolate the year in the release date
budgetinfo['release_date'] = budgetinfo['release_date'].str[-4:]

# %%
#dropping the dollar sign and commas in the production_budget numbers
budgetinfo['production_budget'] = budgetinfo['production_budget'].str.replace('$', '')
budgetinfo['production_budget'] = budgetinfo['production_budget'].str.replace(',', '')

#dropping the dollar sign and commas in the domestic_gross numbers
budgetinfo['domestic_gross'] = budgetinfo['domestic_gross'].str.replace('$', '')
budgetinfo['domestic_gross'] = budgetinfo['domestic_gross'].str.replace(',', '')

#dropping the dollar sign and commas in the worldwide_gross numbers
budgetinfo['worldwide_gross'] = budgetinfo['worldwide_gross'].str.replace('$', '')
budgetinfo['worldwide_gross'] = budgetinfo['worldwide_gross'].str.replace(',', '')
budgetinfo
# Out:
#       id release_date                                        movie  \
# 0      1         2009                                       Avatar
# 1      2         2011  Pirates of the Caribbean: On Stranger Tides
# 2      3         2019                                 Dark Phoenix
# 3      4         2015                      Avengers: Age of Ultron
# 4      5         2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78         2018                                       Red 11
# 5778  79         1999                                    Following
# 5779  80         2005                Return to the Land of Wonders
# 5780  81         2015                         A Plague So Pleasant
# 5781  82         2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0            425000000      760507625      2776345279
# 1            410600000      241063875      1045663875
# 2            350000000       42762350       149762350
# 3            330600000      459005868      1403013963
# 4            317000000      620181382      1316721747
# ...                ...            ...             ...
# 5777              7000              0               0
# 5778              6000          48482          240495
# 5779              5000           1338            1338
# 5780              1400              0               0
# 5781              1100         181041          181041
#
# [5782 rows x 6 columns]

# %%
#convert altered numbers to floats
budgetinfo['worldwide_gross'] = budgetinfo['worldwide_gross'].astype(float)
budgetinfo['production_budget'] = budgetinfo['production_budget'].astype(float)
budgetinfo['domestic_gross'] = budgetinfo['domestic_gross'].astype(float)
budgetinfo
# Out:
#       id release_date                                        movie  \
# 0      1         2009                                       Avatar
# 1      2         2011  Pirates of the Caribbean: On Stranger Tides
# 2      3         2019                                 Dark Phoenix
# 3      4         2015                      Avengers: Age of Ultron
# 4      5         2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78         2018                                       Red 11
# 5778  79         1999                                    Following
# 5779  80         2005                Return to the Land of Wonders
# 5780  81         2015                         A Plague So Pleasant
# 5781  82         2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0           425000000.0     760507625.0     2.776345e+09
# 1           410600000.0     241063875.0     1.045664e+09
# 2           350000000.0      42762350.0     1.497624e+08
# 3           330600000.0     459005868.0     1.403014e+09
# 4           317000000.0     620181382.0     1.316722e+09
# ...                 ...             ...              ...
# 5777             7000.0             0.0     0.000000e+00
# 5778             6000.0         48482.0     2.404950e+05
# 5779             5000.0          1338.0     1.338000e+03
# 5780             1400.0             0.0     0.000000e+00
# 5781             1100.0        181041.0     1.810410e+05
#
# [5782 rows x 6 columns]

# %% [markdown]
# Successfully importing the budget information and converted the columns to workable numbers.
#
# Now, we are going to create an ID column that will allow us to combine the IMDB data with the BudgetInfo data frame.

# %%
budgetinfo["merge_id"] = budgetinfo["release_date"] + " " + budgetinfo["movie"]
budgetinfo
# Out:
#       id release_date                                        movie  \
# 0      1         2009                                       Avatar
# 1      2         2011  Pirates of the Caribbean: On Stranger Tides
# 2      3         2019                                 Dark Phoenix
# 3      4         2015                      Avengers: Age of Ultron
# 4      5         2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78         2018                                       Red 11
# 5778  79         1999                                    Following
# 5779  80         2005                Return to the Land of Wonders
# 5780  81         2015                         A Plague So Pleasant
# 5781  82         2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  \
# 0           425000000.0     760507625.0     2.776345e+09
# 1           410600000.0     241063875.0     1.045664e+09
# 2           350000000.0      42762350.0     1.497624e+08
# 3           330600000.0     459005868.0     1.403014e+09
# 4           317000000.0     620181382.0     1.316722e+09
# ...                 ...             ...              ...
# 5777             7000.0             0.0     0.000000e+00
# 5778             6000.0         48482.0     2.404950e+05
# 5779             5000.0          1338.0     1.338000e+03
# 5780             1400.0             0.0     0.000000e+00
# 5781             1100.0        181041.0     1.810410e+05
#
#                                               merge_id
# 0                                          2009 Avatar
# 1     2011 Pirates of the Caribbean: On Stranger Tides
# 2                                    2019 Dark Phoenix
# 3                         2015 Avengers: Age of Ultron
# 4               2017 Star Wars Ep. VIII: The Last Jedi
# ...                                                ...
# 5777                                       2018 Red 11
# 5778                                    1999 Following
# 5779                2005 Return to the Land of Wonders
# 5780                         2015 A Plague So Pleasant
# 5781                            2005 My Date With Drew
#
# [5782 rows x 7 columns]

# %%
imdb.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
imdb["merge_id"] = imdb["start_year"].astype(str) + " " + imdb["primary_title"]
imdb
# Out:
# <ipython-input-17-8cd98a71fbf7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb["merge_id"] = imdb["start_year"].astype(str) + " " + imdb["primary_title"]
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73849  tt9911774        Padmavyuhathile Abhimanyu   Padmavyuhathile Abhimanyu
# 73850  tt9913056                     Swarm Season                Swarm Season
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
#
#        start_year  runtime_minutes                genres  averagerating  \
# 0            2013            175.0    Action,Crime,Drama            7.0
# 1            2019            114.0       Biography,Drama            7.2
# 2            2018            122.0                 Drama            6.9
# 3            2018              NaN          Comedy,Drama            6.1
# 4            2017             80.0  Comedy,Drama,Fantasy            6.5
# ...           ...              ...                   ...            ...
# 73849        2019            130.0                 Drama            8.4
# 73850        2019             86.0           Documentary            6.2
# 73851        2019             75.0           Documentary            6.2
# 73852        2019             98.0          Drama,Family            8.7
# 73854        2019              NaN                   NaN            6.6
#
#        numvotes                              merge_id
# 0            77                        2013 Sunghursh
# 1            43  2019 One Day Before the Rainy Season
# 2          4517       2018 The Other Side of the Wind
# 3            13                  2018 Sabse Bada Sukh
# 4           119         2017 The Wandering Soap Opera
# ...         ...                                   ...
# 73849       365        2019 Padmavyuhathile Abhimanyu
# 73850         5                     2019 Swarm Season
# 73851         6                 2019 Diabolik sono io
# 73852       136                2019 Sokagin Çocuklari
# 73854         5       2019 La vida sense la Sara Amat
#
# [69993 rows x 9 columns]

# %%
# Locating documentaries in pre-merge
imdb.loc[imdb["genres"] == "Documentary"]
# Out:
#           tconst                       primary_title  \
# 9      tt0159369  Cooper and Hemingway: The True Gen
# 11     tt0170651                T.G.M. - osvoboditel
# 20     tt0262218                   Akakis mogzauroba
# 26     tt0285423                            Abolição
# 73     tt0417750           Hempsters: Plant the Seed
# ...          ...                                 ...
# 73828  tt9899290            Band Together with Logic
# 73840  tt9904844                Ott Tänak: The Movie
# 73843  tt9905476                         Hand Rolled
# 73850  tt9913056                        Swarm Season
# 73851  tt9913084                    Diabolik sono io
#
#                            original_title  start_year  runtime_minutes  \
# 9      Cooper and Hemingway: The True Gen        2013            180.0
# 11                   T.G.M. - osvoboditel        2018             60.0
# 20                      Akakis mogzauroba        2012             44.0
# 26                               Abolição        2019              NaN
# 73              Hempsters: Plant the Seed        2010             90.0
# ...                                   ...         ...              ...
# 73828            Band Together with Logic        2019              NaN
# 73840                Ott Tänak: The Movie        2019            125.0
# 73843                         Hand Rolled        2019             90.0
# 73850                        Swarm Season        2019             86.0
# 73851                    Diabolik sono io        2019             75.0
#
#             genres  averagerating  numvotes  \
# 9      Documentary            7.6        53
# 11     Documentary            7.5         6
# 20     Documentary            7.8        22
# 26     Documentary            7.4        35
# 73     Documentary            7.5       107
# ...            ...            ...       ...
# 73828  Documentary            8.7        10
# 73840  Documentary            8.7       218
# 73843  Documentary            9.3        13
# 73850  Documentary            6.2         5
# 73851  Documentary            6.2         6
#
#                                       merge_id
# 9      2013 Cooper and Hemingway: The True Gen
# 11                   2018 T.G.M. - osvoboditel
# 20                      2012 Akakis mogzauroba
# 26                               2019 Abolição
# 73              2010 Hempsters: Plant the Seed
# ...                                        ...
# 73828            2019 Band Together with Logic
# 73840                2019 Ott Tänak: The Movie
# 73843                         2019 Hand Rolled
# 73850                        2019 Swarm Season
# 73851                    2019 Diabolik sono io
#
# [9992 rows x 9 columns]

# %%
budgetinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   float64
#  4   domestic_gross     5782 non-null   float64
#  5   worldwide_gross    5782 non-null   float64
#  6   merge_id           5782 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 316.3+ KB

# %% [markdown]
# - Creating a matching merge_id for both IMDB and BudgetInfo data frames.
# - We will now combine these two data frames

# %%
movie_data = imdb.set_index("merge_id").join(budgetinfo.set_index("merge_id"),how="inner")

# %%
movie_data = movie_data.reset_index()

# %%
movie_data
# Out:
#                             merge_id     tconst              primary_title  \
# 0                     2010 127 Hours  tt1542344                  127 Hours
# 1     2010 8: The Mormon Proposition  tt1484522  8: The Mormon Proposition
# 2     2010 A Nightmare on Elm Street  tt1179056  A Nightmare on Elm Street
# 3           2010 Alice in Wonderland  tt1014759        Alice in Wonderland
# 4               2010 All Good Things  tt1175709            All Good Things
# ...                              ...        ...                        ...
# 1366                  2019 UglyDolls  tt1946502                  UglyDolls
# 1367                  2019 Unplanned  tt9024106                  Unplanned
# 1368             2019 Velvet Buzzsaw  tt7043012             Velvet Buzzsaw
# 1369              2019 What Men Want  tt7634968              What Men Want
# 1370                2019 Wonder Park  tt6428676                Wonder Park
#
#                  original_title  start_year  runtime_minutes  \
# 0                     127 Hours        2010             94.0
# 1     8: The Mormon Proposition        2010             80.0
# 2     A Nightmare on Elm Street        2010             95.0
# 3           Alice in Wonderland        2010            108.0
# 4               All Good Things        2010            101.0
# ...                         ...         ...              ...
# 1366                  UglyDolls        2019             87.0
# 1367                  Unplanned        2019            106.0
# 1368             Velvet Buzzsaw        2019            113.0
# 1369              What Men Want        2019            117.0
# 1370                Wonder Park        2019             85.0
#
#                           genres  averagerating  numvotes  id release_date  \
# 0      Adventure,Biography,Drama            7.6    323949   6         2010
# 1                    Documentary            7.0      1190  38         2010
# 2             Crime,Drama,Horror            5.2     85497  49         2010
# 3       Adventure,Family,Fantasy            6.5    358813  51         2010
# 4            Crime,Drama,Mystery            6.3     49684  96         2010
# ...                          ...            ...       ...  ..          ...
# 1366  Adventure,Animation,Comedy            4.5      1176   6         2019
# 1367             Biography,Drama            6.3      5945  33         2019
# 1368     Horror,Mystery,Thriller            5.7     40213  82         2019
# 1369      Comedy,Fantasy,Romance            4.9     10141  21         2019
# 1370  Adventure,Animation,Comedy            5.7      3091  94         2019
#
#                           movie  production_budget  domestic_gross  \
# 0                     127 Hours         18000000.0      18335230.0
# 1     8: The Mormon Proposition          2500000.0        100280.0
# 2     A Nightmare on Elm Street         35000000.0      63075011.0
# 3           Alice in Wonderland        200000000.0     334191110.0
# 4               All Good Things         20000000.0        582024.0
# ...                         ...                ...             ...
# 1366                  UglyDolls         45000000.0      19894664.0
# 1367                  Unplanned          6000000.0      18107621.0
# 1368             Velvet Buzzsaw         21000000.0             0.0
# 1369              What Men Want         20000000.0      54611903.0
# 1370                Wonder Park        100000000.0      45216793.0
#
#       worldwide_gross
# 0        6.021717e+07
# 1        1.002800e+05
# 2        1.177296e+08
# 3        1.025491e+09
# 4        8.736170e+05
# ...               ...
# 1366     2.464466e+07
# 1367     1.810762e+07
# 1368     0.000000e+00
# 1369     6.991190e+07
# 1370     1.151494e+08
#
# [1371 rows x 15 columns]

# %%
movie_data = movie_data[["merge_id","release_date","genres","averagerating","numvotes","production_budget","domestic_gross","worldwide_gross"]]

# %%
movie_data
# Out:
#                             merge_id release_date                      genres  \
# 0                     2010 127 Hours         2010   Adventure,Biography,Drama
# 1     2010 8: The Mormon Proposition         2010                 Documentary
# 2     2010 A Nightmare on Elm Street         2010          Crime,Drama,Horror
# 3           2010 Alice in Wonderland         2010    Adventure,Family,Fantasy
# 4               2010 All Good Things         2010         Crime,Drama,Mystery
# ...                              ...          ...                         ...
# 1366                  2019 UglyDolls         2019  Adventure,Animation,Comedy
# 1367                  2019 Unplanned         2019             Biography,Drama
# 1368             2019 Velvet Buzzsaw         2019     Horror,Mystery,Thriller
# 1369              2019 What Men Want         2019      Comedy,Fantasy,Romance
# 1370                2019 Wonder Park         2019  Adventure,Animation,Comedy
#
#       averagerating  numvotes  production_budget  domestic_gross  \
# 0               7.6    323949         18000000.0      18335230.0
# 1               7.0      1190          2500000.0        100280.0
# 2               5.2     85497         35000000.0      63075011.0
# 3               6.5    358813        200000000.0     334191110.0
# 4               6.3     49684         20000000.0        582024.0
# ...             ...       ...                ...             ...
# 1366            4.5      1176         45000000.0      19894664.0
# 1367            6.3      5945          6000000.0      18107621.0
# 1368            5.7     40213         21000000.0             0.0
# 1369            4.9     10141         20000000.0      54611903.0
# 1370            5.7      3091        100000000.0      45216793.0
#
#       worldwide_gross
# 0        6.021717e+07
# 1        1.002800e+05
# 2        1.177296e+08
# 3        1.025491e+09
# 4        8.736170e+05
# ...               ...
# 1366     2.464466e+07
# 1367     1.810762e+07
# 1368     0.000000e+00
# 1369     6.991190e+07
# 1370     1.151494e+08
#
# [1371 rows x 8 columns]

# %%
#see if there is an existing relationship between average rating and the production budget

scatter_title = "Production Budget vs Rating"
xlabel = "Movie Rating"
ylabel = "Production Budget"

productionrating, ax = plt.subplots(figsize=(10,6))
xxx=movie_data["averagerating"]
yyy=movie_data["numvotes"]

ax.scatter(xxx,yyy)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.set_title(scatter_title)
# Out:
# Text(0.5, 1.0, 'Production Budget vs Rating')

# %%
#Run correlation number 0-1
movie_data.corr()
# Out:
#                    averagerating  numvotes  production_budget  domestic_gross  \
# averagerating           1.000000  0.501088           0.224294        0.323762
# numvotes                0.501088  1.000000           0.543450        0.668041
# production_budget       0.224294  0.543450           1.000000        0.710999
# domestic_gross          0.323762  0.668041           0.710999        1.000000
# worldwide_gross         0.305280  0.653669           0.785045        0.943440
#
#                    worldwide_gross
# averagerating             0.305280
# numvotes                  0.653669
# production_budget         0.785045
# domestic_gross            0.943440
# worldwide_gross           1.000000

# %%
#compare production budget to domestic gross
scatter_title = "Production Budget vs Domestic Gross"
ylabel = "Domestic Gross"
xlabel = "Production Budget"

productiondomestic, ax = plt.subplots(figsize=(10,6))
yyyy=movie_data["domestic_gross"]
xxxx=movie_data["production_budget"]

ax.scatter(xxxx,yyyy)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.set_title(scatter_title)
# Out:
# Text(0.5, 1.0, 'Production Budget vs Domestic Gross')

# %%
movie_data
# Out:
#                             merge_id release_date                      genres  \
# 0                     2010 127 Hours         2010   Adventure,Biography,Drama
# 1     2010 8: The Mormon Proposition         2010                 Documentary
# 2     2010 A Nightmare on Elm Street         2010          Crime,Drama,Horror
# 3           2010 Alice in Wonderland         2010    Adventure,Family,Fantasy
# 4               2010 All Good Things         2010         Crime,Drama,Mystery
# ...                              ...          ...                         ...
# 1366                  2019 UglyDolls         2019  Adventure,Animation,Comedy
# 1367                  2019 Unplanned         2019             Biography,Drama
# 1368             2019 Velvet Buzzsaw         2019     Horror,Mystery,Thriller
# 1369              2019 What Men Want         2019      Comedy,Fantasy,Romance
# 1370                2019 Wonder Park         2019  Adventure,Animation,Comedy
#
#       averagerating  numvotes  production_budget  domestic_gross  \
# 0               7.6    323949         18000000.0      18335230.0
# 1               7.0      1190          2500000.0        100280.0
# 2               5.2     85497         35000000.0      63075011.0
# 3               6.5    358813        200000000.0     334191110.0
# 4               6.3     49684         20000000.0        582024.0
# ...             ...       ...                ...             ...
# 1366            4.5      1176         45000000.0      19894664.0
# 1367            6.3      5945          6000000.0      18107621.0
# 1368            5.7     40213         21000000.0             0.0
# 1369            4.9     10141         20000000.0      54611903.0
# 1370            5.7      3091        100000000.0      45216793.0
#
#       worldwide_gross
# 0        6.021717e+07
# 1        1.002800e+05
# 2        1.177296e+08
# 3        1.025491e+09
# 4        8.736170e+05
# ...               ...
# 1366     2.464466e+07
# 1367     1.810762e+07
# 1368     0.000000e+00
# 1369     6.991190e+07
# 1370     1.151494e+08
#
# [1371 rows x 8 columns]

# %%
#compare production budget to WORLDWIDE gross
scatter_title = "Production Budget vs Worldwide Gross"
ylabel = "Worldwide Gross"
xlabel = "Production Budget"

productiondomestic, ax = plt.subplots(figsize=(10,6))
yyyyy=movie_data["worldwide_gross"]
xxxxx=movie_data["production_budget"]

ax.scatter(xxxxx,yyyyy)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.set_title(scatter_title)
# Out:
# Text(0.5, 1.0, 'Production Budget vs Worldwide Gross')

# %%
movies_with_profit = movie_data.loc[movie_data["worldwide_gross"] != 0]
movies_with_profit
# Out:
#                             merge_id release_date                      genres  \
# 0                     2010 127 Hours         2010   Adventure,Biography,Drama
# 1     2010 8: The Mormon Proposition         2010                 Documentary
# 2     2010 A Nightmare on Elm Street         2010          Crime,Drama,Horror
# 3           2010 Alice in Wonderland         2010    Adventure,Family,Fantasy
# 4               2010 All Good Things         2010         Crime,Drama,Mystery
# ...                              ...          ...                         ...
# 1365  2019 The Secret Life of Pets 2         2019  Adventure,Animation,Comedy
# 1366                  2019 UglyDolls         2019  Adventure,Animation,Comedy
# 1367                  2019 Unplanned         2019             Biography,Drama
# 1369              2019 What Men Want         2019      Comedy,Fantasy,Romance
# 1370                2019 Wonder Park         2019  Adventure,Animation,Comedy
#
#       averagerating  numvotes  production_budget  domestic_gross  \
# 0               7.6    323949         18000000.0      18335230.0
# 1               7.0      1190          2500000.0        100280.0
# 2               5.2     85497         35000000.0      63075011.0
# 3               6.5    358813        200000000.0     334191110.0
# 4               6.3     49684         20000000.0        582024.0
# ...             ...       ...                ...             ...
# 1365            6.6      3467         80000000.0      63795655.0
# 1366            4.5      1176         45000000.0      19894664.0
# 1367            6.3      5945          6000000.0      18107621.0
# 1369            4.9     10141         20000000.0      54611903.0
# 1370            5.7      3091        100000000.0      45216793.0
#
#       worldwide_gross
# 0        6.021717e+07
# 1        1.002800e+05
# 2        1.177296e+08
# 3        1.025491e+09
# 4        8.736170e+05
# ...               ...
# 1365     1.133515e+08
# 1366     2.464466e+07
# 1367     1.810762e+07
# 1369     6.991190e+07
# 1370     1.151494e+08
#
# [1276 rows x 8 columns]

# %% [markdown]
# ### Comparing production budget to WORLDWIDE gross, not including any movies with no profits

# %%
scatter_title = "Production Budget vs Worldwide Gross (Profitable Movies Only)"
ylabel = "Worldwide Gross"
xlabel = "Production Budget"

productiondomesticprofit, ax = plt.subplots(figsize=(10,6))
yyyyyy=movies_with_profit["worldwide_gross"]
xxxxxx=movies_with_profit["production_budget"]

ax.scatter(xxxxxx,yyyyyy)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.set_title(scatter_title)
# Out:
# Text(0.5, 1.0, 'Production Budget vs Worldwide Gross (Profitable Movies Only)')

# %%
movies_with_profit.corr()
# Out:
#                    averagerating  numvotes  production_budget  domestic_gross  \
# averagerating           1.000000  0.503474           0.184605        0.303401
# numvotes                0.503474  1.000000           0.525941        0.656937
# production_budget       0.184605  0.525941           1.000000        0.701121
# domestic_gross          0.303401  0.656937           0.701121        1.000000
# worldwide_gross         0.287384  0.643272           0.779163        0.941765
#
#                    worldwide_gross
# averagerating             0.287384
# numvotes                  0.643272
# production_budget         0.779163
# domestic_gross            0.941765
# worldwide_gross           1.000000

# %% [markdown]
# There is almost a perfect correlation between domestic gross and worldwide gross.
#
# A very strong correlation between production budget and your profits, domestic and worldwide - with stronger relationship between production budget and worldwide profit

# %%
movies_with_profit["d_profit"] = movies_with_profit["domestic_gross"] - movies_with_profit["production_budget"]
movies_with_profit
# Out:
# <ipython-input-33-060001520960>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_with_profit["d_profit"] = movies_with_profit["domestic_gross"] - movies_with_profit["production_budget"]
#                             merge_id release_date                      genres  \
# 0                     2010 127 Hours         2010   Adventure,Biography,Drama
# 1     2010 8: The Mormon Proposition         2010                 Documentary
# 2     2010 A Nightmare on Elm Street         2010          Crime,Drama,Horror
# 3           2010 Alice in Wonderland         2010    Adventure,Family,Fantasy
# 4               2010 All Good Things         2010         Crime,Drama,Mystery
# ...                              ...          ...                         ...
# 1365  2019 The Secret Life of Pets 2         2019  Adventure,Animation,Comedy
# 1366                  2019 UglyDolls         2019  Adventure,Animation,Comedy
# 1367                  2019 Unplanned         2019             Biography,Drama
# 1369              2019 What Men Want         2019      Comedy,Fantasy,Romance
# 1370                2019 Wonder Park         2019  Adventure,Animation,Comedy
#
#       averagerating  numvotes  production_budget  domestic_gross  \
# 0               7.6    323949         18000000.0      18335230.0
# 1               7.0      1190          2500000.0        100280.0
# 2               5.2     85497         35000000.0      63075011.0
# 3               6.5    358813        200000000.0     334191110.0
# 4               6.3     49684         20000000.0        582024.0
# ...             ...       ...                ...             ...
# 1365            6.6      3467         80000000.0      63795655.0
# 1366            4.5      1176         45000000.0      19894664.0
# 1367            6.3      5945          6000000.0      18107621.0
# 1369            4.9     10141         20000000.0      54611903.0
# 1370            5.7      3091        100000000.0      45216793.0
#
#       worldwide_gross     d_profit
# 0        6.021717e+07     335230.0
# 1        1.002800e+05   -2399720.0
# 2        1.177296e+08   28075011.0
# 3        1.025491e+09  134191110.0
# 4        8.736170e+05  -19417976.0
# ...               ...          ...
# 1365     1.133515e+08  -16204345.0
# 1366     2.464466e+07  -25105336.0
# 1367     1.810762e+07   12107621.0
# 1369     6.991190e+07   34611903.0
# 1370     1.151494e+08  -54783207.0
#
# [1276 rows x 9 columns]

# %%
movies_with_profit["w_profit"] = movies_with_profit["worldwide_gross"] - movies_with_profit["production_budget"]
movies_with_profit
# Out:
# <ipython-input-34-d5b0e16c7566>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_with_profit["w_profit"] = movies_with_profit["worldwide_gross"] - movies_with_profit["production_budget"]
#                             merge_id release_date                      genres  \
# 0                     2010 127 Hours         2010   Adventure,Biography,Drama
# 1     2010 8: The Mormon Proposition         2010                 Documentary
# 2     2010 A Nightmare on Elm Street         2010          Crime,Drama,Horror
# 3           2010 Alice in Wonderland         2010    Adventure,Family,Fantasy
# 4               2010 All Good Things         2010         Crime,Drama,Mystery
# ...                              ...          ...                         ...
# 1365  2019 The Secret Life of Pets 2         2019  Adventure,Animation,Comedy
# 1366                  2019 UglyDolls         2019  Adventure,Animation,Comedy
# 1367                  2019 Unplanned         2019             Biography,Drama
# 1369              2019 What Men Want         2019      Comedy,Fantasy,Romance
# 1370                2019 Wonder Park         2019  Adventure,Animation,Comedy
#
#       averagerating  numvotes  production_budget  domestic_gross  \
# 0               7.6    323949         18000000.0      18335230.0
# 1               7.0      1190          2500000.0        100280.0
# 2               5.2     85497         35000000.0      63075011.0
# 3               6.5    358813        200000000.0     334191110.0
# 4               6.3     49684         20000000.0        582024.0
# ...             ...       ...                ...             ...
# 1365            6.6      3467         80000000.0      63795655.0
# 1366            4.5      1176         45000000.0      19894664.0
# 1367            6.3      5945          6000000.0      18107621.0
# 1369            4.9     10141         20000000.0      54611903.0
# 1370            5.7      3091        100000000.0      45216793.0
#
#       worldwide_gross     d_profit     w_profit
# 0        6.021717e+07     335230.0   42217171.0
# 1        1.002800e+05   -2399720.0   -2399720.0
# 2        1.177296e+08   28075011.0   82729621.0
# 3        1.025491e+09  134191110.0  825491110.0
# 4        8.736170e+05  -19417976.0  -19126383.0
# ...               ...          ...          ...
# 1365     1.133515e+08  -16204345.0   33351496.0
# 1366     2.464466e+07  -25105336.0  -20355336.0
# 1367     1.810762e+07   12107621.0   12107621.0
# 1369     6.991190e+07   34611903.0   49911903.0
# 1370     1.151494e+08  -54783207.0   15149422.0
#
# [1276 rows x 10 columns]

# %%
movies_with_profit.corr()
# Out:
#                    averagerating  numvotes  production_budget  domestic_gross  \
# averagerating           1.000000  0.503474           0.184605        0.303401
# numvotes                0.503474  1.000000           0.525941        0.656937
# production_budget       0.184605  0.525941           1.000000        0.701121
# domestic_gross          0.303401  0.656937           0.701121        1.000000
# worldwide_gross         0.287384  0.643272           0.779163        0.941765
# d_profit                0.251990  0.427269           0.044691        0.743664
# w_profit                0.294009  0.625172           0.651214        0.935385
#
#                    worldwide_gross  d_profit  w_profit
# averagerating             0.287384  0.251990  0.294009
# numvotes                  0.643272  0.427269  0.625172
# production_budget         0.779163  0.044691  0.651214
# domestic_gross            0.941765  0.743664  0.935385
# worldwide_gross           1.000000  0.588902  0.983093
# d_profit                  0.588902  1.000000  0.699929
# w_profit                  0.983093  0.699929  1.000000

# %% [markdown]
# ### Determine the Return On Investment (ROI),  add Domestic and Worldwide ROI numbers to profitable movies dataframe

# %% [markdown]
# ROI = (net profit / gross) * 100

# %%
movies_with_profit["w_roi"] = movies_with_profit["worldwide_gross"] / movies_with_profit["production_budget"]
movies_with_profit["d_roi"] = movies_with_profit["domestic_gross"] / movies_with_profit["production_budget"]
movies_with_profit
# Out:
# <ipython-input-36-ef5a4e297eb8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_with_profit["w_roi"] = movies_with_profit["worldwide_gross"] / movies_with_profit["production_budget"]
# <ipython-input-36-ef5a4e297eb8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_with_profit["d_roi"] = movies_with_profit["domestic_gross"] / movies_with_profit["production_budget"]
#                             merge_id release_date                      genres  \
# 0                     2010 127 Hours         2010   Adventure,Biography,Drama
# 1     2010 8: The Mormon Proposition         2010                 Documentary
# 2     2010 A Nightmare on Elm Street         2010          Crime,Drama,Horror
# 3           2010 Alice in Wonderland         2010    Adventure,Family,Fantasy
# 4               2010 All Good Things         2010         Crime,Drama,Mystery
# ...                              ...          ...                         ...
# 1365  2019 The Secret Life of Pets 2         2019  Adventure,Animation,Comedy
# 1366                  2019 UglyDolls         2019  Adventure,Animation,Comedy
# 1367                  2019 Unplanned         2019             Biography,Drama
# 1369              2019 What Men Want         2019      Comedy,Fantasy,Romance
# 1370                2019 Wonder Park         2019  Adventure,Animation,Comedy
#
#       averagerating  numvotes  production_budget  domestic_gross  \
# 0               7.6    323949         18000000.0      18335230.0
# 1               7.0      1190          2500000.0        100280.0
# 2               5.2     85497         35000000.0      63075011.0
# 3               6.5    358813        200000000.0     334191110.0
# 4               6.3     49684         20000000.0        582024.0
# ...             ...       ...                ...             ...
# 1365            6.6      3467         80000000.0      63795655.0
# 1366            4.5      1176         45000000.0      19894664.0
# 1367            6.3      5945          6000000.0      18107621.0
# 1369            4.9     10141         20000000.0      54611903.0
# 1370            5.7      3091        100000000.0      45216793.0
#
#       worldwide_gross     d_profit     w_profit     w_roi     d_roi
# 0        6.021717e+07     335230.0   42217171.0  3.345398  1.018624
# 1        1.002800e+05   -2399720.0   -2399720.0  0.040112  0.040112
# 2        1.177296e+08   28075011.0   82729621.0  3.363703  1.802143
# 3        1.025491e+09  134191110.0  825491110.0  5.127456  1.670956
# 4        8.736170e+05  -19417976.0  -19126383.0  0.043681  0.029101
# ...               ...          ...          ...       ...       ...
# 1365     1.133515e+08  -16204345.0   33351496.0  1.416894  0.797446
# 1366     2.464466e+07  -25105336.0  -20355336.0  0.547659  0.442104
# 1367     1.810762e+07   12107621.0   12107621.0  3.017937  3.017937
# 1369     6.991190e+07   34611903.0   49911903.0  3.495595  2.730595
# 1370     1.151494e+08  -54783207.0   15149422.0  1.151494  0.452168
#
# [1276 rows x 12 columns]

# %% [markdown]
# ## Budget and Genres Analysis

# %% [markdown]
# - Starting to combine Budget and

# %%
genre = movies_with_profit
split = genre['genres'].str.split(",", expand = True)
genre['one']= split[0]
genre['two']= split[1]
genre['three']= split[2]
# Out:
# <ipython-input-41-41fbc1e7093e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['one']= split[0]
# <ipython-input-41-41fbc1e7093e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['two']= split[1]
# <ipython-input-41-41fbc1e7093e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['three']= split[2]

# %%
g1 = genre[['averagerating', 'numvotes', 'production_budget', 'domestic_gross', 'worldwide_gross','d_profit','w_profit', 'w_roi', "d_roi", 'one']].rename(columns={'one':'genre'})
g2 = genre[['averagerating', 'numvotes', 'production_budget', 'domestic_gross', 'worldwide_gross','d_profit','w_profit', 'w_roi', "d_roi", 'two']].rename(columns={'two':'genre'})
g3 = genre[['averagerating', 'numvotes', 'production_budget', 'domestic_gross', 'worldwide_gross','d_profit','w_profit', 'w_roi', "d_roi", 'three']].rename(columns={'three':'genre'})
genres_list = [g1, g2, g3]
genres = pd.concat(genres_list)
genres.dropna(inplace=True)

# %%
g2
# Out:
#       averagerating  numvotes  production_budget  domestic_gross  \
# 0               7.6    323949         18000000.0      18335230.0
# 1               7.0      1190          2500000.0        100280.0
# 2               5.2     85497         35000000.0      63075011.0
# 3               6.5    358813        200000000.0     334191110.0
# 4               6.3     49684         20000000.0        582024.0
# ...             ...       ...                ...             ...
# 1365            6.6      3467         80000000.0      63795655.0
# 1366            4.5      1176         45000000.0      19894664.0
# 1367            6.3      5945          6000000.0      18107621.0
# 1369            4.9     10141         20000000.0      54611903.0
# 1370            5.7      3091        100000000.0      45216793.0
#
#       worldwide_gross     d_profit     w_profit     w_roi     d_roi      genre
# 0        6.021717e+07     335230.0   42217171.0  3.345398  1.018624  Biography
# 1        1.002800e+05   -2399720.0   -2399720.0  0.040112  0.040112       None
# 2        1.177296e+08   28075011.0   82729621.0  3.363703  1.802143      Drama
# 3        1.025491e+09  134191110.0  825491110.0  5.127456  1.670956     Family
# 4        8.736170e+05  -19417976.0  -19126383.0  0.043681  0.029101      Drama
# ...               ...          ...          ...       ...       ...        ...
# 1365     1.133515e+08  -16204345.0   33351496.0  1.416894  0.797446  Animation
# 1366     2.464466e+07  -25105336.0  -20355336.0  0.547659  0.442104  Animation
# 1367     1.810762e+07   12107621.0   12107621.0  3.017937  3.017937      Drama
# 1369     6.991190e+07   34611903.0   49911903.0  3.495595  2.730595    Fantasy
# 1370     1.151494e+08  -54783207.0   15149422.0  1.151494  0.452168  Animation
#
# [1276 rows x 10 columns]

# %%
genres
# Out:
#       averagerating  numvotes  production_budget  domestic_gross  \
# 0               7.6    323949         18000000.0      18335230.0
# 1               7.0      1190          2500000.0        100280.0
# 2               5.2     85497         35000000.0      63075011.0
# 3               6.5    358813        200000000.0     334191110.0
# 4               6.3     49684         20000000.0        582024.0
# ...             ...       ...                ...             ...
# 1364            7.4     10383         25000000.0             0.0
# 1365            6.6      3467         80000000.0      63795655.0
# 1366            4.5      1176         45000000.0      19894664.0
# 1369            4.9     10141         20000000.0      54611903.0
# 1370            5.7      3091        100000000.0      45216793.0
#
#       worldwide_gross     d_profit     w_profit     w_roi     d_roi  \
# 0        6.021717e+07     335230.0   42217171.0  3.345398  1.018624
# 1        1.002800e+05   -2399720.0   -2399720.0  0.040112  0.040112
# 2        1.177296e+08   28075011.0   82729621.0  3.363703  1.802143
# 3        1.025491e+09  134191110.0  825491110.0  5.127456  1.670956
# 4        8.736170e+05  -19417976.0  -19126383.0  0.043681  0.029101
# ...               ...          ...          ...       ...       ...
# 1364     5.227233e+06  -25000000.0  -19772767.0  0.209089  0.000000
# 1365     1.133515e+08  -16204345.0   33351496.0  1.416894  0.797446
# 1366     2.464466e+07  -25105336.0  -20355336.0  0.547659  0.442104
# 1369     6.991190e+07   34611903.0   49911903.0  3.495595  2.730595
# 1370     1.151494e+08  -54783207.0   15149422.0  1.151494  0.452168
#
#             genre
# 0       Adventure
# 1     Documentary
# 2           Crime
# 3       Adventure
# 4           Crime
# ...           ...
# 1364      Mystery
# 1365       Comedy
# 1366       Comedy
# 1369      Romance
# 1370       Comedy
#
# [3318 rows x 10 columns]

# %%
genres["genre"].value_counts()
# Out:
# Drama          612
# Comedy         463
# Action         396
# Adventure      327
# Thriller       213
# Crime          203
# Romance        174
# Horror         136
# Biography      120
# Sci-Fi         116
# Fantasy        113
# Mystery        107
# Animation       95
# Family          81
# Music           44
# History         37
# Sport           26
# Documentary     25
# War             15
# Western          9
# Musical          6
# Name: genre, dtype: int64

# %%
genres['genre'][1363]
# Out:
# 1363      Horror
# 1363    Thriller
# Name: genre, dtype: object

# %%
# plot comparing genres of profitable movies vs their production budgets
production = genres[['production_budget', 'genre']]
sns.set_theme(style = "ticks", color_codes = True)
sns.catplot(x='genre', y='production_budget', data = production, aspect=20/10)
plt.xticks(rotation = 45);

# %%
wprofit = genres[['w_profit', 'genre']]
sns.set_theme(style = "ticks", color_codes = True)
sns.catplot(x='genre', y='w_profit', data = wprofit, aspect=20/10)
plt.xticks(rotation = 45);

# %%
genres.to_csv('genres')

# %% [markdown]
# ## Analyzing Profitability and Genres

# %%
#grouping by genres to assertain how successful particular genres are and link them to certain metrics

genres_t = genres

# %%
genres_t = genres.groupby(by=["genre"]).describe().T

# %%
genres_t

# %%
genres_mean = genres.groupby(by=["genre"]).mean().T

# %%
genres_mean

# %%
droi_by_genre = genres_t.loc["d_roi"]

# %%
droi_by_genre

# %%
# most frequently made genres
#documentary has one of highest ROIs, hgihest ratings, less saturated market due to lower # count
# highest average ROI genres
# family has very high number of votes,, lots of people watching these, very popular

# %%
### TRYING TO: gather the genres that are not over saturated, aka have a lower "count". then see which ones have highest ratings
genres_count = genres["genre"].count()
genres_count
#droi_by_lowcount_and_rating = genres_count.loc["averagerating"]

# %%
average_rating = genres_t.loc["averagerating"].T
average_rating[average_rating["count"] < 300]

# %%
droi_by_lowcount_and_rating.sort_values()

# %%
quickgroup = genres.groupby(["genre"])["d_roi","averagerating","numvotes"].mean()
quickgroup.sort_values("d_roi", ascending=False)

# %%
quickgroup = genres.groupby(["genre"])["d_roi","averagerating","numvotes"].median()
quickgroup.sort_values("averagerating", ascending=False)
